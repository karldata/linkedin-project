# %%
#To change the working directory
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Applied-Semester-Project')
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/Applied-Semester-Project

# %%
import csv
import pandas as pd

# %%
df = pd.read_csv("output.csv")
df
# Out:
#                                  Name  ...                                                URL
# 0        Latha Sankeerthana Duddugala  ...     https://www.linkedin.com/in/latha-sankeerthana
# 1                          Swati Wagh  ...          https://www.linkedin.com/in/swati-wagh-01
# 2             Kiran Kumar Balabommala  ...  https://www.linkedin.com/in/kiran-kumar-balabo...
# 3                    Haoyu (Clara) Su  ...  https://www.linkedin.com/in/haoyu-clara-su-b58...
# 4     Hemant Dwivedy , MBA, PMP®, PSM  ...  https://www.linkedin.com/in/hemant-dwivedy-mba...
# ...                               ...  ...                                                ...
# 2438                     VAMSIDHAR Y.  ...   https://www.linkedin.com/in/vamsidhar-y-44196191
# 2439                      Patricia S.  ...   https://www.linkedin.com/in/patricia-s-1a3458173
# 2440                      Marc Ethier  ...   https://www.linkedin.com/in/marc-ethier-74564784
# ...

# %%
skills_series = df['Skills']
type(skills_series)
# Out:
# pandas.core.series.Series

# %%
skill_list = skills_series.tolist()
skill_list

# %%
skills = []
for i in range(len(skill_list)):
  skills.append(str(skill_list[i]).split(", "))
skills
type(skills)
# Out:
# list

# %%
skills_string = ' '.join(str(skill) for skill in skills)
skills_string_replace1 = skills_string.replace("[", "")
skills_string_replace1
# Out:
# '\'SQL\', \'Data Mining\', \'Exploratory Data Analysis\', \'Data Structures and Algorithms\', \'Machine Learning\', \'Network Security\', \'Data Visualization\', \'Database Administration\', \'Administrative Assistance\', \'Data Analysis\', \'C (Programming Language)\', \'Python (Programming Language)\', \'R\', \'Microsoft Office\', \'Microsoft Excel\', \'Linux\', \'HTML\', \'Amazon Web Services (AWS)\', \'Microsoft PowerPoint\', \'Tableau\', \'Operating Systems\', \'Database Management System (DBMS)\', \'Weka\', \'Sharcnet\', \'OpenMP\', \'MPI\', \'Hybrid\', \'High Performance Computing (HPC)\', \'Natural Language Processing (NLP)\'] \'Abinitio Development\', \'Data Analysis\', \'Unix\', \'Extract\', \'Transform\', \'Load (ETL)\', \'Data Structures\', \'Machine Learning\', \'Big Data\', \'Software Development\', \'Data Science\', \'Data Visualization\', \'Data visualization\', \'Oracle Database\', \'Informatica\', \'SQL\', \'Java\', \'C++\', \'C\', \'PowerPoint\', \'HTML\', \'Micros
# ...

# %%
skills_string_replace2 = skills_string_replace1.replace("'", "")
skills_string_replace2
# Out:
# 'SQL, Data Mining, Exploratory Data Analysis, Data Structures and Algorithms, Machine Learning, Network Security, Data Visualization, Database Administration, Administrative Assistance, Data Analysis, C (Programming Language), Python (Programming Language), R, Microsoft Office, Microsoft Excel, Linux, HTML, Amazon Web Services (AWS), Microsoft PowerPoint, Tableau, Operating Systems, Database Management System (DBMS), Weka, Sharcnet, OpenMP, MPI, Hybrid, High Performance Computing (HPC), Natural Language Processing (NLP)] Abinitio Development, Data Analysis, Unix, Extract, Transform, Load (ETL), Data Structures, Machine Learning, Big Data, Software Development, Data Science, Data Visualization, Data visualization, Oracle Database, Informatica, SQL, Java, C++, C, PowerPoint, HTML, Microsoft SQL Server, MongoDB, Python, Oracle SQL Developer, Microsoft Excel, Python (Programming Language), R (Programming Language), Tableau, PySpark, Microsoft Office, Leadership, Teamwork, English, Object
# ...

# %%
wordcloud = WordCloud(width = 1000, height = 500, max_words=30).generate(skills_string_replace2)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()

# %%
import requests
import urllib.parse

address = 'Ontario, Canada'
url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'

response = requests.get(url).json()
print(response[0]["lat"])
print(response[0]["lon"])
# Out:
# 50.000678
# -86.000977
